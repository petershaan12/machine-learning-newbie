# %%
import pandas as pd
data = pd.read_csv("data/U3_02_Celsius.csv")

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   celsius     7 non-null      int64
#  1   fahrenheit  7 non-null      float64
# dtypes: float64(1), int64(1)
# memory usage: 244.0 bytes

# %%
data.head()
# Out:
#    celsius  fahrenheit
# 0      -40       -40.0
# 1      -10        14.0
# 2        0        32.0
# 3        8        46.4
# 4       15        59.0

# %%
import seaborn as sb

sb.scatterplot(x="celsius", y="fahrenheit", data=data,
               hue="fahrenheit", palette="coolwarm")
# Out:
# <Axes: xlabel='celsius', ylabel='fahrenheit'>

# %%
#Caracteristic (X), Label (Y)
X = data["celsius"]
Y = data["fahrenheit"]

# %%
Y
# Out:
# 0    -40.0
# 1     14.0
# 2     32.0
# 3     46.4
# 4     59.0
# 5     71.6
# 6    100.4
# Name: fahrenheit, dtype: float64

# %%
X.values
# [-40, -10, ...]
# [[-40], [-10], ...]
# Out:
# array([-40, -10,   0,   8,  15,  22,  38])

# %%
X_prosess=X.values.reshape(-1, 1)
Y_prosess=Y.values.reshape(-1, 1)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
# Pelatihan
model.fit(X_prosess, Y_prosess)
# Out:
# LinearRegression()

# %%
celsius = -40
prediksi = model.predict([[celsius]])
print(f"{celsius} drajat adalah {prediksi} drajat fahrenheit")
# Out:
# -40 drajat adalah [[-40.]] drajat fahrenheit

# %%
model.score(X_prosess, Y_prosess)
# Out:
# 1.0
